# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from river import drift
from sklearn.datasets import make_classification

# %%
def get_data():
    df  = pd.read_csv("rt_8873985678962563_gradual.csv")

    features, labels = [], []

    for i in range(len(df)):
        features.append([df.loc[i, "X1"], df.loc[i, "X2"]])
        labels.append(df.loc[i, "class"])

    return np.array(features), np.array(labels)

# Generate the dataset
features, labels = get_data()

# features, labels

# %%
# Auxiliary function to plot the detected drifts
def plot_drifts(features, labels, drifts):
    plt.figure(figsize=(10, 6))
    plt.scatter(features[:, 0], features[:, 1], c=labels, alpha=0.5, cmap='coolwarm')
    for drift_detected in drifts:
        plt.axvline(x=drift_detected, color='red', linestyle='--')
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.title('Detected Drifts')
    plt.show()

# %%
# Drift detection
drift_detector = drift.ADWIN()
drifts = []

for i, (feature, label) in enumerate(zip(features, labels)):
    drift_detector.update(label)   # Here we are using the label for drift detection
    if drift_detector.drift_detected:
        print(f'Change detected at index {i}')
        drifts.append(i)
#         drift_detector.reset()   # Resetting the detector after a drift is detected


# print(drifts)
plot_drifts(features, labels, drifts)
# Out:
# Change detected at index 11263
# Change detected at index 21055
# Change detected at index 31007

# %%
drift_detector = drift.KSWIN()
drifts = []

for i, (feature, label) in enumerate(zip(features, labels)):
    drift_detector.update(label)   # Here we are using the label for drift detection
    if drift_detector.drift_detected:
        print(f'Change detected at index {i}')
        drifts.append(i)
#         drift_detector.reset()   # Resetting the detector after a drift is detected

# print(drifts)
plot_drifts(features, labels, drifts)
# Out:
# Change detected at index 4623
# Change detected at index 20819
# Change detected at index 30540
# Change detected at index 33997
# Change detected at index 34279
# Change detected at index 36247

# %%
drift_detector = drift.DummyDriftDetector()
drifts = []

for i, (feature, label) in enumerate(zip(features, labels)):
    drift_detector.update(label)   # Here we are using the label for drift detection
    if drift_detector.drift_detected:
        print(f'Change detected at index {i}')
        drifts.append(i)
#         drift_detector.reset()   # Resetting the detector after a drift is detected

# print(drifts)
plot_drifts(features, labels, drifts)
# Out:
# Change detected at index 299
# Change detected at index 599
# Change detected at index 899
# Change detected at index 1199
# Change detected at index 1499
# Change detected at index 1799
# Change detected at index 2099
# Change detected at index 2399
# Change detected at index 2699
# Change detected at index 2999
# Change detected at index 3299
# Change detected at index 3599
# Change detected at index 3899
# Change detected at index 4199
# Change detected at index 4499
# Change detected at index 4799
# Change detected at index 5099
# Change detected at index 5399
# Change detected at index 5699
# Change detected at index 5999
# Change detected at index 6299
# Change detected at index 6599
# Change detected at index 6899
# Change detected at index 7199
# Change detected at index 7499
# Change detected at index 7799
# Change detected at index 8099
# Change detected at index 8399
# Change detected at index 8699
# Change detected at index 8999
# Change detected at index 9299
# Change detected at index 9599
# Change detected at index 9899
# Change detected at index 10199
# Change detected at index 10499
# Change detected at index 10799
# Change detected at index 11099
# Change detected at index 11399
# Change detected at index 11699
# Change detected at index 11999
# Change detected at index 12299
# Change detected at index 12599
# Change detected at index 12899
# Change detected at index 13199
# Change detected at index 13499
# Change detected at index 13799
# Change detected at index 14099
# Change detected at index 14399
# Change detected at index 14699
# Change detected at index 14999
# Change detected at index 15299
# Change detected at index 15599
# Change detected at index 15899
# Change detected at index 16199
# Change detected at index 16499
# Change detected at index 16799
# Change detected at index 17099
# Change detected at index 17399
# Change detected at index 17699
# Change detected at index 17999
# Change detected at index 18299
# Change detected at index 18599
# Change detected at index 18899
# Change detected at index 19199
# Change detected at index 19499
# Change detected at index 19799
# Change detected at index 20099
# Change detected at index 20399
# Change detected at index 20699
# Change detected at index 20999
# Change detected at index 21299
# Change detected at index 21599
# Change detected at index 21899
# Change detected at index 22199
# Change detected at index 22499
# Change detected at index 22799
# Change detected at index 23099
# Change detected at index 23399
# Change detected at index 23699
# Change detected at index 23999
# Change detected at index 24299
# Change detected at index 24599
# Change detected at index 24899
# Change detected at index 25199
# Change detected at index 25499
# Change detected at index 25799
# Change detected at index 26099
# Change detected at index 26399
# Change detected at index 26699
# Change detected at index 26999
# Change detected at index 27299
# Change detected at index 27599
# Change detected at index 27899
# Change detected at index 28199
# Change detected at index 28499
# Change detected at index 28799
# Change detected at index 29099
# Change detected at index 29399
# Change detected at index 29699
# Change detected at index 29999
# Change detected at index 30299
# Change detected at index 30599
# Change detected at index 30899
# Change detected at index 31199
# Change detected at index 31499
# Change detected at index 31799
# Change detected at index 32099
# Change detected at index 32399
# Change detected at index 32699
# Change detected at index 32999
# Change detected at index 33299
# Change detected at index 33599
# Change detected at index 33899
# Change detected at index 34199
# Change detected at index 34499
# Change detected at index 34799
# Change detected at index 35099
# Change detected at index 35399
# Change detected at index 35699
# Change detected at index 35999
# Change detected at index 36299
# Change detected at index 36599
# Change detected at index 36899
# Change detected at index 37199
# Change detected at index 37499
# Change detected at index 37799
# Change detected at index 38099
# Change detected at index 38399
# Change detected at index 38699
# Change detected at index 38999
# Change detected at index 39299
# Change detected at index 39599
# Change detected at index 39899
# Change detected at index 40199
# Change detected at index 40499
# Change detected at index 40799

# %%
drift_detector = drift.PageHinkley()
drifts = []

for i, (feature, label) in enumerate(zip(features, labels)):
    drift_detector.update(label)   # Here we are using the label for drift detection
    if drift_detector.drift_detected:
        print(f'Change detected at index {i}')
        drifts.append(i)
#         drift_detector.reset()   # Resetting the detector after a drift is detected

# print(drifts)
plot_drifts(features, labels, drifts)
# Out:
# Change detected at index 5603
# Change detected at index 10254
# Change detected at index 19785
# Change detected at index 20788
# Change detected at index 22631
# Change detected at index 30548
# Change detected at index 31419
# Change detected at index 34547
