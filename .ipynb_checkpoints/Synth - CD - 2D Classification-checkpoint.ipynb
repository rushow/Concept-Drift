# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from river.datasets import synth

# Create an instance of the FriedmanDrift dataset
dataset = synth.FriedmanDrift(
    drift_type='lea',
    position=(1000, 2000, 3000),
    seed=29
)
print(dataset)

# Simulate a data stream from the FriedmanDrift dataset
stream = [y for _, y in dataset.take(5000)]  # Taking 5000 samples

# Auxiliary function to plot the data
def plot_data(stream, drifts=None):
    fig = plt.figure(figsize=(10,5), tight_layout=True)
    gs = gridspec.GridSpec(1, 1)
    ax1 = plt.subplot(gs[0])
    ax1.grid()
    ax1.plot(stream, label='Stream')
    if drifts is not None:
        for drift_detected in drifts:
            ax1.axvline(drift_detected, color='red')
    plt.show()

plot_data(stream)
# Out:
# Synthetic data generator
#
#     Name  FriedmanDrift
#     Task  Regression
#  Samples  ∞
# Features  10
#   Sparse  False
#
# Configuration
# -------------
#        drift_type  lea
#          position  (1000, 2000, 3000)
# transition_window  10000
#              seed  29
